# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_unified = pd.read_csv('../iniciais/base_unificada_parkinson.csv')
df_unified
# Out:
#              Entity Code_x  Year_x  \
# 0       Afghanistan    AFG    2000
# 1       Afghanistan    AFG    2000
# 2       Afghanistan    AFG    2000
# 3       Afghanistan    AFG    2000
# 4       Afghanistan    AFG    2000
# ...             ...    ...     ...
# 109195     Zimbabwe    ZWE    2019
# 109196     Zimbabwe    ZWE    2019
# 109197     Zimbabwe    ZWE    2019
# 109198     Zimbabwe    ZWE    2019
# 109199     Zimbabwe    ZWE    2019
#
#         Death rate per 100,000 people - Cause: Parkinson disease - Sex: Both sexes - Age_group: ALLAges  \
# 0                                                    1.45
# 1                                                    1.45
# 2                                                    1.45
# 3                                                    1.45
# 4                                                    1.45
# ...                                                   ...
# 109195                                               1.55
# ...

# %%
df_unified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109200 entries, 0 to 109199
# Data columns (total 7 columns):
#  #   Column                                                                                                  Non-Null Count   Dtype
# ---  ------                                                                                                  --------------   -----
#  0   Entity                                                                                                  109200 non-null  object
#  1   Code_x                                                                                                  109200 non-null  object
#  2   Year_x                                                                                                  109200 non-null  int64
#  3   Death rate per 100,000 people - Cause: Parkinson disease - Sex: Both sexes - Age_group: ALLAges         109200 non-null  float64
# ...

# %%
columns_drop = ['Code_y']
df_final = df_unified.drop(columns_drop, axis=1)
df_final
# Out:
#              Entity Code_x  Year_x  \
# 0       Afghanistan    AFG    2000
# 1       Afghanistan    AFG    2000
# 2       Afghanistan    AFG    2000
# 3       Afghanistan    AFG    2000
# 4       Afghanistan    AFG    2000
# ...             ...    ...     ...
# 109195     Zimbabwe    ZWE    2019
# 109196     Zimbabwe    ZWE    2019
# 109197     Zimbabwe    ZWE    2019
# 109198     Zimbabwe    ZWE    2019
# 109199     Zimbabwe    ZWE    2019
#
#         Death rate per 100,000 people - Cause: Parkinson disease - Sex: Both sexes - Age_group: ALLAges  \
# 0                                                    1.45
# 1                                                    1.45
# 2                                                    1.45
# 3                                                    1.45
# 4                                                    1.45
# ...                                                   ...
# 109195                                               1.55
# ...

# %%
df_final = pd.read_csv('base_analise_parkinson.csv')
df_final
# Out:
#              Entity Code_x  Year_x  \
# 0       Afghanistan    AFG    2000
# 1       Afghanistan    AFG    2000
# 2       Afghanistan    AFG    2000
# 3       Afghanistan    AFG    2000
# 4       Afghanistan    AFG    2000
# ...             ...    ...     ...
# 109195     Zimbabwe    ZWE    2019
# 109196     Zimbabwe    ZWE    2019
# 109197     Zimbabwe    ZWE    2019
# 109198     Zimbabwe    ZWE    2019
# 109199     Zimbabwe    ZWE    2019
#
#         Death rate per 100,000 people - Cause: Parkinson disease - Sex: Both sexes - Age_group: ALLAges  \
# 0                                                    1.45
# 1                                                    1.45
# 2                                                    1.45
# 3                                                    1.45
# 4                                                    1.45
# ...                                                   ...
# 109195                                               1.55
# ...

# %%
translate = {
    'Entity': 'País',
    'Code_x': 'Sigla',
    'Year_x': 'Ano morte',
    'Death rate per 100,000 people - Cause: Parkinson disease - Sex: Both sexes - Age_group: ALLAges	': 'Taxa de mortalidade por 100 mil',
    'Year_y': 'Ano doença',
    "Current number of cases of parkinson's disease per 100,000 people, in both sexes aged age-standardized": 'Número atual de casos por 100 mil',
}

new_columns = []
for chave, valor in translate.items():
    new_columns.append(valor)

print(new_columns)
# Out:
# ['País', 'Sigla', 'Ano morte', 'Taxa de mortalidade por 100 mil', 'Ano doença', 'Número atual de casos por 100 mil']

# %%
df_final.columns = new_columns
df_final
# Out:
#                País Sigla  Ano morte  Taxa de mortalidade por 100 mil  \
# 0       Afghanistan   AFG       2000                             1.45
# 1       Afghanistan   AFG       2000                             1.45
# 2       Afghanistan   AFG       2000                             1.45
# 3       Afghanistan   AFG       2000                             1.45
# 4       Afghanistan   AFG       2000                             1.45
# ...             ...   ...        ...                              ...
# 109195     Zimbabwe   ZWE       2019                             1.55
# 109196     Zimbabwe   ZWE       2019                             1.55
# 109197     Zimbabwe   ZWE       2019                             1.55
# 109198     Zimbabwe   ZWE       2019                             1.55
# 109199     Zimbabwe   ZWE       2019                             1.55
#
#         Ano doença  Número atual de casos por 100 mil
# 0             1990                          71.658936
# ...

# %%
df_final.to_csv('base_analise_parkinson.csv', index=False)

# %%
# Filtrando os dados para que mostre apenas o país Brasil e anos a partir de 2012

df_filtered = df_final[(df_final['Ano morte'] > 2011) & (df_final['País'] == 'Brazil')]
df_filtered.shape
# Out:
# (240, 6)

# %%
sns.scatterplot(x='Ano morte', y='Taxa de mortalidade por 100 mil', data=df_filtered, hue='Taxa de mortalidade por 100 mil', palette='viridis')
plt.title('Média de morte por ano no Brasil')
plt.xlabel('Ano morte')
plt.ylabel('Taxa de mortalidade por 100 mil')
plt.show()

# %%
sns.scatterplot(x='Ano doença', y='Número atual de casos por 100 mil', data=df_filtered, hue='Número atual de casos por 100 mil', palette='viridis')
plt.title('Média de doença por ano no Brasil')
plt.xlabel('Ano doença')
plt.ylabel('Número atual de casos por 100 mil')
plt.show()

# %%
# Filtrando os dados para que mostre apenas a taxa de mortalidade em 2012

df_filtered_2012 = df_final[(df_final['Ano morte'] == 2012)]
df_filtered_2012.shape
# Out:
# (5460, 6)

# %%
# Filtrando os dados para que mostre apenas a taxa de mortalidade em 2012

df_filtered_2019 = df_final[(df_final['Ano doença'] == 2012)]
df_filtered_2019.shape
# Out:
# (3640, 6)

# %% [markdown]
# # O que pretendedemos com essa análise?
#
# - Descobrir quantas pessoas convivem com Parkinson entre os anos de 2012 a 2019 no Brasil.
# - Descobrir quantas pessoas faleceram entre os anos de 2012 a 2019 que tinham Parkinson no Brasil.
# - Qual o país teve maior taxa de mortalidade em pessoas que tinham Parkinson em 2012.
# - Qual o top 5 em países  que tinham mais mortalidade em pessoas que tinham Parkinson em 2012.
# - Qual o país tem mais pessoas diagnosticadas com Parkinson em 2019.
# - Qual o top 5 em países que tinham mais pessoas diagnosticadas com Parkinson em 2019.
